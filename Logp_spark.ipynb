# %%
# Uncomment below if needed
# !pip install deepchem rdkit-pypi pyspark

import time
import numpy as np
import pandas as pd
from rdkit import Chem
import deepchem as dc
from deepchem.feat import ConvMolFeaturizer
from deepchem.models import GraphConvModel
from deepchem.splits import RandomSplitter
from deepchem.models.optimizers import ExponentialDecay
import logging
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.types import BooleanType, DoubleType
from tqdm import tqdm
from deepchem.metrics import Metric, pearson_r2_score, mean_absolute_error

# Logging setup
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Initialize Spark
spark = SparkSession.builder.appName("LogPPredictor").getOrCreate()
# Out:
# INFO:py4j.clientserver:Error while sending or receiving.
# Traceback (most recent call last):
#   File "/home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/py4j/clientserver.py", line 503, in send_command
#     self.socket.sendall(command.encode("utf-8"))
# ConnectionResetError: [Errno 104] Connection reset by peer
# INFO:py4j.clientserver:Closing down clientserver connection
# INFO:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/py4j/clientserver.py", line 503, in send_command
#     self.socket.sendall(command.encode("utf-8"))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/py4j/clientserver.py", line 506, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending
# INFO:py4j.clientserver:Closing down clientserver connection

# %%
class LogPPredictor:
    def __init__(self):
        self.metrics = {
            'performance': {'train_r2': None, 'test_r2': None, 'test_mae': None},
            'timing': {'total_training': None}
        }
        self.featurizer = ConvMolFeaturizer()
        self.model = None
        self.dataset = None
        self.dataset_df = None

    def load_data(self, data_paths):
        logger.info("Loading and processing data...")
        dfs = []
        for path in data_paths:
            try:
                df = spark.read.csv(path, header=True, inferSchema=True)
                target_col = next((c for c in ['exp', 'logP'] if c in df.columns), None)
                if not target_col:
                    raise ValueError("Dataset must contain 'exp' or 'logP'")
                if target_col == 'logP':
                    df = df.withColumnRenamed('logP', 'exp')
                df = df.select('smiles', 'exp')

                validate_smiles = udf(lambda x: Chem.MolFromSmiles(x) is not None, BooleanType())
                df = df.filter(validate_smiles(col('smiles')))
                df = df.withColumn('exp', col('exp').cast(DoubleType())) \
                       .filter(col('exp').isNotNull()) \
                       .filter((col('exp') >= -10) & (col('exp') <= 10))
                dfs.append(df)
            except Exception as e:
                logger.error(f"Failed loading {path}: {e}")
                raise

        if not dfs:
            raise ValueError("No valid datasets loaded")

        combined_df = dfs[0]
        for df in dfs[1:]:
            combined_df = combined_df.union(df)

        pandas_df = combined_df.toPandas()
        features = self.featurizer.featurize(pandas_df['smiles'].apply(Chem.MolFromSmiles))
        valid_indices = [i for i, f in enumerate(features) if f is not None]
        valid_features = [f for f in features if f is not None]

        self.dataset = dc.data.NumpyDataset(
            X=np.array(valid_features),
            y=pandas_df['exp'].values[valid_indices]
        )
        self.dataset_df = pandas_df.iloc[valid_indices]
        logger.info("Featurization complete.")

    def train_model(self, max_epochs=200, patience=20):
        if not self.dataset:
            raise ValueError("No dataset to train on.")

        splitter = RandomSplitter()
        train, valid, test = splitter.train_valid_test_split(
            self.dataset, frac_train=0.7, frac_valid=0.15, frac_test=0.15, seed=42
        )

        lr_schedule = ExponentialDecay(0.001, decay_rate=0.95, decay_steps=1000)
        self.model = GraphConvModel(
            n_tasks=1, mode='regression',
            graph_conv_layers=[128, 128, 64],
            dense_layer_size=256, dropout=0.3,
            batch_size=32,
            optimizer_kwargs={'learning_rate': lr_schedule},
            batch_normalize=False
        )

        best_score = -float('inf')
        no_improve = 0
        start = time.time()

        print("🧠 Training started...")
        for epoch in tqdm(range(max_epochs), desc="Epochs"):
            self.model.fit(train, nb_epoch=1)

            val_score = self.model.evaluate(valid, [Metric(pearson_r2_score)])['pearson_r2_score']
            if val_score > best_score:
                best_score = val_score
                no_improve = 0
                self.model.save_checkpoint()
            else:
                no_improve += 1

            if no_improve >= patience:
                logger.info(f"⏹ Early stopping at epoch {epoch} (best R² = {best_score:.4f})")
                break

        self.model.restore()
        self.metrics['timing']['total_training'] = time.time() - start

        metrics = [Metric(pearson_r2_score), Metric(mean_absolute_error)]
        self.metrics['performance']['train_r2'] = self.model.evaluate(train, metrics)['pearson_r2_score']
        test_results = self.model.evaluate(test, metrics)
        self.metrics['performance']['test_r2'] = test_results['pearson_r2_score']
        self.metrics['performance']['test_mae'] = test_results['mean_absolute_error']

        print(f"✅ Training finished in {self.metrics['timing']['total_training']:.2f} seconds")
        print(f"Train R²: {self.metrics['performance']['train_r2']:.3f}")
        print(f"Test R²: {self.metrics['performance']['test_r2']:.3f}")
        print(f"Test MAE: {self.metrics['performance']['test_mae']:.3f}")

    def predict_logP(self, smiles):
        mol = Chem.MolFromSmiles(smiles)
        if not mol:
            raise ValueError("Invalid SMILES")
        feat = self.featurizer.featurize([mol])
        if not feat or feat[0] is None:
            raise ValueError("Featurization failed")
        return float(self.model.predict(dc.data.NumpyDataset(X=np.array(feat)))[0][0])

# %%
predictor = LogPPredictor()

DATA_PATHS = [
    "/home/mounir/Downloads/Lipophilicity.csv",
    "/home/mounir/Downloads/logP_dataset.csv"
]

predictor.load_data(DATA_PATHS)
# Out:
# INFO:__main__:Loading and processing data...
# INFO:deepchem.feat.base_classes:Featurizing datapoint 0
# INFO:deepchem.feat.base_classes:Featurizing datapoint 1000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 2000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 3000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 4000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 5000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 6000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 7000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 8000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 9000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 10000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 11000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 12000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 13000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 14000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 15000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 16000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 17000
# INFO:deepchem.feat.base_classes:Featurizing datapoint 18000
# INFO:__main__:Featurization complete.

# %%
print("Training model...")
predictor.train_model()
# Out:
# INFO:deepchem.splits.splitters:Computing train/valid/test indices
# Training model...
# 🧠 Training started...
# Epochs:   0%|                                           | 0/200 [00:00<?, ?it/s]/home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_14:0", shape=(96,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_13:0", shape=(96, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_17:0", shape=(492,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_16:0", shape=(492, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_20:0", shape=(330,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_19:0", shape=(330, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_23:0", shape=(32,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Reshape_22:0", shape=(32, 64), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_11/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_11:0", shape=(96,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_10:0", shape=(96, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_13:0", shape=(492,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_12:0", shape=(492, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_15:0", shape=(330,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_14:0", shape=(330, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_2:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_17:0", shape=(32,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_16:0", shape=(32, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_3:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_19:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_18:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_21:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_20:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_23:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_22:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_6:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_25:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_24:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_7:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_27:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_26:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_8:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_29:0", shape=(0,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Reshape_28:0", shape=(0, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_conv_11/Cast_9:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape_14:0", shape=(96,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape_13:0", shape=(96, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape_17:0", shape=(492,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape_16:0", shape=(492, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Cast_5:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /home/mounir/spark_logp_fixed_env/lib/python3.10/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape_20:0", shape=(330,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_3/graph_pool_10/Reshape
# INFO:deepchem.models.keras_model:TIMING: model fitting took 6.627 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8446281345154928]
# Epochs:   6%|█▊                                | 11/200 [01:34<23:08,  7.35s/it]INFO:deepchem.models.keras_model:Ending global_step 4600: Average loss 0.327215
# INFO:deepchem.models.keras_model:Ending global_step 4700: Average loss 0.296626
# INFO:deepchem.models.keras_model:Ending global_step 4800: Average loss 0.338672
# INFO:deepchem.models.keras_model:Ending global_step 4900: Average loss 0.361373
# INFO:deepchem.models.keras_model:Ending global_step 4944: Average loss 0.317617
# INFO:deepchem.models.keras_model:TIMING: model fitting took 6.726 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8304063002519239]
# Epochs:   6%|██                                | 12/200 [01:41<22:50,  7.29s/it]INFO:deepchem.models.keras_model:Ending global_step 5000: Average loss 0.377805
# INFO:deepchem.models.keras_model:Ending global_step 5100: Average loss 0.321789
# INFO:deepchem.models.keras_model:Ending global_step 5200: Average loss 0.362726
# INFO:deepchem.models.keras_model:Ending global_step 5300: Average loss 0.314917
# INFO:deepchem.models.keras_model:Ending global_step 5356: Average loss 0.318602
# INFO:deepchem.models.keras_model:TIMING: model fitting took 6.682 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8529264460294704]
# Epochs:   6%|██▏                               | 13/200 [01:48<22:42,  7.28s/it]INFO:deepchem.models.keras_model:Ending global_step 5400: Average loss 0.312943
# INFO:deepchem.models.keras_model:Ending global_step 5500: Average loss 0.309762
# INFO:deepchem.models.keras_model:Ending global_step 5600: Average loss 0.305164
# INFO:deepchem.models.keras_model:Ending global_step 5700: Average loss 0.362864
# INFO:deepchem.models.keras_model:Ending global_step 5768: Average loss 0.330547
# INFO:deepchem.models.keras_model:TIMING: model fitting took 6.548 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8397085799589599]
# Epochs:   7%|██▍                               | 14/200 [01:55<22:17,  7.19s/it]INFO:deepchem.models.keras_model:Ending global_step 5800: Average loss 0.312432
# INFO:deepchem.models.keras_model:Ending global_step 5900: Average loss 0.313097
# INFO:deepchem.models.keras_model:Ending global_step 6000: Average loss 0.309524
# INFO:deepchem.models.keras_model:Ending global_step 6100: Average loss 0.313121
# INFO:deepchem.models.keras_model:Ending global_step 6180: Average loss 0.334639
# INFO:deepchem.models.keras_model:TIMING: model fitting took 6.715 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8466250115555002]
# Epochs:   8%|██▌                               | 15/200 [02:03<22:07,  7.18s/it]INFO:deepchem.models.keras_model:Ending global_step 6200: Average loss 0.285569
# INFO:deepchem.models.keras_model:Ending global_step 6300: Average loss 0.300124
# INFO:deepchem.models.keras_model:Ending global_step 6400: Average loss 0.343292
# INFO:deepchem.models.keras_model:Ending global_step 6500: Average loss 0.329962
# INFO:deepchem.models.keras_model:Ending global_step 6592: Average loss 0.314301
# ...
# INFO:deepchem.models.keras_model:Ending global_step 12200: Average loss 0.297244
# INFO:deepchem.models.keras_model:Ending global_step 12300: Average loss 0.320441
# INFO:deepchem.models.keras_model:Ending global_step 12360: Average loss 0.316352
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.195 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.271 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8503241692984659]
# Epochs:  22%|███████▎                          | 43/200 [05:37<20:15,  7.74s/it]INFO:deepchem.models.keras_model:Ending global_step 17800: Average loss 0.319831
# INFO:deepchem.models.keras_model:Ending global_step 17900: Average loss 0.296351
# INFO:deepchem.models.keras_model:Ending global_step 18000: Average loss 0.308677
# INFO:deepchem.models.keras_model:Ending global_step 18100: Average loss 0.32733
# INFO:deepchem.models.keras_model:Ending global_step 18128: Average loss 0.291164
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.751 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8542255506645734]
# Epochs:  22%|███████▍                          | 44/200 [05:45<20:28,  7.87s/it]INFO:deepchem.models.keras_model:Ending global_step 18200: Average loss 0.316244
# INFO:deepchem.models.keras_model:Ending global_step 18300: Average loss 0.311801
# INFO:deepchem.models.keras_model:Ending global_step 18400: Average loss 0.326914
# INFO:deepchem.models.keras_model:Ending global_step 18500: Average loss 0.313415
# INFO:deepchem.models.keras_model:Ending global_step 18540: Average loss 0.330561
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.363 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8555962218763679]
# Epochs:  22%|███████▋                          | 45/200 [05:53<20:17,  7.85s/it]INFO:deepchem.models.keras_model:Ending global_step 18600: Average loss 0.286117
# INFO:deepchem.models.keras_model:Ending global_step 18700: Average loss 0.315141
# INFO:deepchem.models.keras_model:Ending global_step 18800: Average loss 0.30193
# INFO:deepchem.models.keras_model:Ending global_step 18900: Average loss 0.297646
# INFO:deepchem.models.keras_model:Ending global_step 18952: Average loss 0.314527
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.191 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8457322098652692]
# Epochs:  23%|███████▊                          | 46/200 [06:00<20:00,  7.79s/it]INFO:deepchem.models.keras_model:Ending global_step 19000: Average loss 0.28424
# INFO:deepchem.models.keras_model:Ending global_step 19100: Average loss 0.326314
# INFO:deepchem.models.keras_model:Ending global_step 19200: Average loss 0.290484
# INFO:deepchem.models.keras_model:Ending global_step 19300: Average loss 0.292814
# INFO:deepchem.models.keras_model:Ending global_step 19364: Average loss 0.330932
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.293 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8511900492506544]
# Epochs:  24%|███████▉                          | 47/200 [06:08<19:49,  7.77s/it]INFO:deepchem.models.keras_model:Ending global_step 19400: Average loss 0.351241
# INFO:deepchem.models.keras_model:Ending global_step 19500: Average loss 0.306804
# INFO:deepchem.models.keras_model:Ending global_step 19600: Average loss 0.299837
# INFO:deepchem.models.keras_model:Ending global_step 19700: Average loss 0.312057
# INFO:deepchem.models.keras_model:Ending global_step 19776: Average loss 0.317889
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.318 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8460086086600287]
# Epochs:  24%|████████▏                         | 48/200 [06:16<19:41,  7.77s/it]INFO:deepchem.models.keras_model:Ending global_step 19800: Average loss 0.323369
# INFO:deepchem.models.keras_model:Ending global_step 19900: Average loss 0.30177
# INFO:deepchem.models.keras_model:Ending global_step 20000: Average loss 0.316937
# INFO:deepchem.models.keras_model:Ending global_step 20100: Average loss 0.336983
# INFO:deepchem.models.keras_model:Ending global_step 20188: Average loss 0.343308
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.438 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8471733536535266]
# Epochs:  24%|████████▎                         | 49/200 [06:24<19:39,  7.81s/it]INFO:deepchem.models.keras_model:Ending global_step 20200: Average loss 0.327332
# INFO:deepchem.models.keras_model:Ending global_step 20300: Average loss 0.325907
# INFO:deepchem.models.keras_model:Ending global_step 20400: Average loss 0.345291
# INFO:deepchem.models.keras_model:Ending global_step 20500: Average loss 0.323948
# INFO:deepchem.models.keras_model:Ending global_step 20600: Average loss 0.29676
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.186 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8560018340735185]
# Epochs:  25%|████████▌                         | 50/200 [06:31<19:24,  7.76s/it]INFO:deepchem.models.keras_model:Ending global_step 20700: Average loss 0.29015
# INFO:deepchem.models.keras_model:Ending global_step 20800: Average loss 0.304473
# INFO:deepchem.models.keras_model:Ending global_step 20900: Average loss 0.333272
# INFO:deepchem.models.keras_model:Ending global_step 21000: Average loss 0.335938
# INFO:deepchem.models.keras_model:Ending global_step 21012: Average loss 0.254873
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.365 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8441441587372609]
# Epochs:  26%|████████▋                         | 51/200 [06:39<19:18,  7.77s/it]INFO:deepchem.models.keras_model:Ending global_step 21100: Average loss 0.293695
# INFO:deepchem.models.keras_model:Ending global_step 21200: Average loss 0.33528
# INFO:deepchem.models.keras_model:Ending global_step 21300: Average loss 0.324072
# INFO:deepchem.models.keras_model:Ending global_step 21400: Average loss 0.335173
# INFO:deepchem.models.keras_model:Ending global_step 21424: Average loss 0.343305
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.323 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8460847182201281]
# Epochs:  26%|████████▊                         | 52/200 [06:47<19:09,  7.77s/it]INFO:deepchem.models.keras_model:Ending global_step 21500: Average loss 0.310246
# INFO:deepchem.models.keras_model:Ending global_step 21600: Average loss 0.304226
# INFO:deepchem.models.keras_model:Ending global_step 21700: Average loss 0.376815
# INFO:deepchem.models.keras_model:Ending global_step 21800: Average loss 0.366142
# INFO:deepchem.models.keras_model:Ending global_step 21836: Average loss 0.332573
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.596 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8426224830113075]
# Epochs:  26%|█████████                         | 53/200 [06:55<19:13,  7.85s/it]INFO:deepchem.models.keras_model:Ending global_step 21900: Average loss 0.317101
# INFO:deepchem.models.keras_model:Ending global_step 22000: Average loss 0.300715
# INFO:deepchem.models.keras_model:Ending global_step 22100: Average loss 0.291611
# INFO:deepchem.models.keras_model:Ending global_step 22200: Average loss 0.324955
# INFO:deepchem.models.keras_model:Ending global_step 22248: Average loss 0.38502
# INFO:deepchem.models.keras_model:TIMING: model fitting took 7.354 s
# INFO:deepchem.metrics.metric:computed_metrics: [0.8390745095952008]
# INFO:__main__:⏹ Early stopping at epoch 53 (best R² = 0.8589)
# Epochs:  26%|█████████                         | 53/200 [07:03<19:33,  7.99s/it]
# INFO:deepchem.metrics.metric:computed_metrics: [0.8468129209950083]
# INFO:deepchem.metrics.metric:computed_metrics: [0.3953158988396808]
# INFO:deepchem.metrics.metric:computed_metrics: [0.8417489547857523]
# INFO:deepchem.metrics.metric:computed_metrics: [0.40949094144135056]
# ✅ Training finished in 423.36 seconds
# Train R²: 0.847
# Test R²: 0.842
# Test MAE: 0.409

# %%
print("\n=== Evaluation Metrics ===")
print(f"Train R²: {predictor.metrics['performance']['train_r2']:.3f}")
print(f"Test R²: {predictor.metrics['performance']['test_r2']:.3f}")
print(f"Test MAE: {predictor.metrics['performance']['test_mae']:.3f}")
print(f"Training Time: {predictor.metrics['timing']['total_training']:.2f} seconds")
# Out:
# === Evaluation Metrics ===
# Train R²: 0.847
# Test R²: 0.842
# Test MAE: 0.409
# Training Time: 423.36 seconds

# %%
from IPython.display import display, clear_output
from ipywidgets import widgets
from rdkit import Chem
from rdkit.Chem import Draw

def predict_logP_interval_direct(smiles, model, featurizer):
    """Predict logP ± 0.5 range for a given SMILES"""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        raise ValueError("Invalid SMILES string")

    features = featurizer.featurize([mol])
    dataset = dc.data.NumpyDataset(features)
    prediction = model.predict(dataset)[0][0]
    return prediction - 0.5, prediction + 0.5

def launch_simple_predictor_interface(model, featurizer, dataset_df=None):
    """Interactive logP prediction interface"""
    smiles_input = widgets.Text(
        value='CCO',
        placeholder='Enter SMILES (e.g., CCO)',
        description='SMILES:',
        layout=widgets.Layout(width='80%')
    )
    
    predict_button = widgets.Button(
        description="Predict", button_style='info'
    )
    output = widgets.Output()

    def make_prediction(_):
        with output:
            clear_output(wait=True)
            smiles = smiles_input.value.strip()
            if not smiles:
                print("Please enter a SMILES string.")
                return

            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol:
                    display(Draw.MolToImage(mol, size=(300, 300)))
                else:
                    print("Invalid SMILES string.")
                    return

                if dataset_df is not None and smiles in dataset_df['smiles'].values:
                    actual = dataset_df[dataset_df['smiles'] == smiles]['exp'].values[0]
                    print(f"Known compound - Actual logP: {actual:.2f}")

                low, high = predict_logP_interval_direct(smiles, model, featurizer)
                print(f"\nPredicted logP range: {low:.2f} to {high:.2f}")
                print(f"Estimated logP: {(low + high)/2:.2f}")

                # Simple interpretation
                if high < 0:
                    print("💧 Highly hydrophilic (water-soluble)")
                elif low < 1:
                    print("🧪 Moderately hydrophilic")
                elif high < 3:
                    print("⚖️ Balanced solubility")
                elif low < 5:
                    print("🛢 Moderately hydrophobic")
                else:
                    print("🔥 Highly hydrophobic (lipid-soluble)")

            except Exception as e:
                print(f"Prediction error: {str(e)}")

    predict_button.on_click(make_prediction)

    display(widgets.VBox([
        widgets.HTML("<h2 style='color:#1f77b4;'>LogP Predictor Interface</h2>"),
        widgets.HTML("<p>Enter a SMILES string to estimate its logP and solubility interpretation</p>"),
        widgets.HBox([smiles_input, predict_button]),
        output
    ]))

# Run this after model training
launch_simple_predictor_interface(
    model=predictor.model,
    featurizer=predictor.featurizer,
    dataset_df=predictor.dataset_df
)
# Out:
# VBox(children=(HTML(value="<h2 style='color:#1f77b4;'>LogP Predictor Interface</h2>"), HTML(value='<p>Enter a …

# %%
pip list
# Out:
# IOStream.flush timed out
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.2.2
# anyio                        4.9.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# cachetools                   5.5.2
# certifi                      2025.1.31
# cffi                         1.17.1
# charset-normalizer           3.4.1
# comm                         0.2.2
# contourpy                    1.3.1
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# deepchem                     2.7.1
# defusedxml                   0.7.1
# exceptiongroup               1.2.2
# executing                    2.2.0
# fastjsonschema               2.21.1
# flatbuffers                  25.2.10
# fonttools                    4.57.0
# fqdn                         1.5.1
# gast                         0.4.0
# google-auth                  2.38.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.71.0
# h11                          0.16.0
# h5py                         3.13.0
# httpcore                     1.0.9
# httpx                        0.28.1
# idna                         3.10
# ipykernel                    6.29.5
# ipython                      8.36.0
# ipywidgets                   8.1.6
# isoduration                  20.11.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.4.2
# json5                        0.12.0
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2025.4.1
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.12.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.15.0
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.4.1
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.3
# jupyterlab_widgets           3.0.14
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.8
# libclang                     18.1.1
# Markdown                     3.8
# markdown-it-py               3.0.0
# MarkupSafe                   3.0.2
# matplotlib                   3.10.1
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mistune                      3.1.3
# ml_dtypes                    0.5.1
# mpmath                       1.3.0
# namex                        0.0.8
# nbclient                     0.10.2
# nbconvert                    7.16.6
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# notebook                     7.4.1
# notebook_shim                0.2.4
# numpy                        1.24.4
# oauthlib                     3.2.2
# opt_einsum                   3.4.0
# optree                       0.15.0
# overrides                    7.7.0
# packaging                    24.2
# pandas                       2.2.3
# pandocfilters                1.5.1
# parso                        0.8.4
# pexpect                      4.9.0
# pillow                       11.1.0
# pip                          22.0.2
# platformdirs                 4.3.7
# prometheus_client            0.21.1
# prompt_toolkit               3.0.51
# protobuf                     3.19.6
# psutil                       7.0.0
# ptyprocess                   0.7.0
# pure_eval                    0.2.3
# py4j                         0.10.9.7
# pyasn1                       0.6.1
# pyasn1_modules               0.4.2
# pycparser                    2.22
# Pygments                     2.19.1
# pyparsing                    3.2.3
# pyspark                      3.5.5
# python-dateutil              2.9.0.post0
# python-json-logger           3.3.0
# pytz                         2025.2
# PyYAML                       6.0.2
# pyzmq                        26.4.0
# rdkit                        2024.9.6
# referencing                  0.36.2
# requests                     2.32.3
# requests-oauthlib            2.0.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         14.0.0
# rpds-py                      0.24.0
# rsa                          4.9
# scikit-learn                 1.6.1
# scipy                        1.8.1
# seaborn                      0.13.2
# Send2Trash                   1.8.3
# setuptools                   59.6.0
# six                          1.17.0
# sniffio                      1.3.1
# soupsieve                    2.7
# stack-data                   0.6.3
# sympy                        1.13.3
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.1
# tensorflow-estimator         2.10.0
# tensorflow-io-gcs-filesystem 0.37.1
# termcolor                    3.0.1
# terminado                    0.18.1
# threadpoolctl                3.6.0
# tinycss2                     1.4.0
# tomli                        2.2.1
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# types-python-dateutil        2.9.0.20241206
# typing_extensions            4.13.2
# tzdata                       2025.2
# uri-template                 1.3.0
# urllib3                      2.4.0
# wcwidth                      0.2.13
# webcolors                    24.11.1
# webencodings                 0.5.1
# websocket-client             1.8.0
# Werkzeug                     3.1.3
# wheel                        0.45.1
# widgetsnbextension           4.0.14
# wrapt                        1.17.2
# Note: you may need to restart the kernel to use updated packages.
